# %%
import pandas as pd
from langdetect import detect
import string
import emoji
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS
from sklearn.metrics.pairwise import cosine_similarity
import requests
import boto3
import json

import os # for touching a file to restart when new model file is generatd

import nltk
from nltk import word_tokenize 
from nltk.stem import WordNetLemmatizer 
nltk.download('punkt')
nltk.download('wordnet')

# for cortex
import cloudpickle

pd.set_option('display.max_rows',500)
# Out:
# [nltk_data] Downloading package punkt to /Users/dlite/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/dlite/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
########################################################
### Import Dataset
########################################################

# %%
raw_github_data = pd.read_csv('../data/external/2020-04-06.tsv', sep='\t', header=0)
raw_github_data.head(2)
# Out:
#                                github_repo_url  \
# 0   https://github.com/CSSEGISandData/COVID-19
# 1  https://github.com/phildini/stayinghomeclub
#
#                                     repo_description  \
# 0  novel coronavirus (covid-19) cases, provided b...
# 1  a list of all the companies wfh or events chan...
#
#                                               topics  \
# 0  systems-science, covid-19, johns-hopkins-unive...
# 1        remote-work, covid19, covid-19, static-site
#
#             owner_repo_name      owner_name owner_type organization_bio  \
# 0   CSSEGISandData/COVID-19  CSSEGISandData       User              NaN
# 1  phildini/stayinghomeclub        phildini       User              NaN
#
#   repo_created_day primary_language_name license_name  ...  count_of_stars  \
# 0       2020-02-04                   NaN          NaN  ...           19434
# 1       2020-03-04                  Ruby      cc0-1.0  ...             456
#
#    count_of_watchers  count_distinct_contributors  count_contributions  \
# 0              19417                         2746                11609
# 1                453                         1091                 4156
#
#    count_commits  count_commit_comments  count_created_issues  \
# 0           3256                    152                  1669
# 1           1293                      3                    78
#
#    count_pull_requests_created  count_pull_requests_reviews  \
# 0                          361                          119
# 1                         1350                          934
#
#    count_comments_on_issues_and_pull_requests
# 0                                        6052
# 1                                         498
#
# [2 rows x 28 columns]

# %%
########################################################
### Clean Dataset
########################################################

# %%
# Filtering down to repos that are likely needing contributors based on past behavior
raw_github_data_filtered = raw_github_data[(raw_github_data['has_merged_prs'] == True) &
    (raw_github_data['has_readme'] == True) &
    (pd.isna(raw_github_data['repo_description']) == False) &
    (pd.isna(raw_github_data['primary_language_name']) == False) &
    (raw_github_data['count_distinct_contributors'] >=2)
]

# %%
raw_github_data_filtered.fillna(value = '',inplace=True)
# Out:
# /Users/dlite/projects/ml_examples/covid19-repo-recommender/venv/lib/python3.7/site-packages/pandas/core/frame.py:4153: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   downcast=downcast,

# %%
# Detect language with error handling
def detect_with_error_handle(x):
    try:
        return detect(x)
    except:
        return 'Error'
    
# Check for only latin characters
def has_only_latin_letters(text):
    char_set = string.printable + '—'
    return all((True if x in char_set else False for x in text))

# Remove punctuation
def remove_punctuation(text):
    punctuation_list = string.punctuation + '—'
    return text.translate(str.maketrans('', '', punctuation_list))

# %%
## Full set of text processing

# check language, limit to english, and limit repo's with latin characters. Emojis are converted in the process
raw_github_data_filtered['language'] = raw_github_data_filtered['repo_description'].apply(lambda x: 'None' if pd.isna(x) else detect_with_error_handle(str(x)))
raw_github_data_filtered = raw_github_data_filtered[raw_github_data_filtered['language'] == 'en'].copy()
raw_github_data_filtered['is_latin_only_characters'] = raw_github_data_filtered['repo_description'].apply(lambda x: has_only_latin_letters(emoji.demojize(x)))
raw_github_data_filtered = raw_github_data_filtered[raw_github_data_filtered['is_latin_only_characters'] == True].copy()

# clean up repo description, topic, and language, combine into one big bag o' words
raw_github_data_filtered['repo_description_cleaned'] = raw_github_data_filtered['repo_description'].apply(lambda x: remove_punctuation(x))
raw_github_data_filtered['topics'] = raw_github_data_filtered.apply(lambda x: remove_punctuation(str(x['topics']).replace(',','').replace('nan','')), axis=1)
raw_github_data_filtered['topics'].fillna('', inplace=True)
raw_github_data_filtered['description_plus_topics'] = raw_github_data_filtered['repo_description_cleaned']+' '+raw_github_data_filtered['topics']+' '+raw_github_data_filtered['primary_language_name']
raw_github_data_filtered.reset_index(drop=True, inplace=True)

repo_lookup = raw_github_data_filtered
# Out:
# /Users/dlite/projects/ml_examples/covid19-repo-recommender/venv/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
########################################################
### Tokenize
########################################################

# %%
# Create class to be used by tokenizer to lemmatize... which change matches words to their roots
class LemmaTokenizer(object):
    def __init__(self):
        self.wnl = WordNetLemmatizer()
    def __call__(self, articles):
        return [self.wnl.lemmatize(t) for t in word_tokenize(articles)]

# %%
# Create a list of stop words that should be removed before tokenizing
stopwords = list(ENGLISH_STOP_WORDS) + ['covid19','coronavirus','virus','corona','covid','pandemic','sarscov2','outbreak','19','disease','2019','2019ncov','cord19','repository','repo','2020','20','covid2019','covidvirus', 'cases','case']

# Create vectorizor of n-grams using stop words and lemmatizer
word_vectorizer = CountVectorizer(ngram_range=(1,1), analyzer='word',stop_words=stopwords, tokenizer=LemmaTokenizer())

# Fit vectorizer on existing list of repos and create sparse matrix
sparse_vector_matrix = word_vectorizer.fit_transform(raw_github_data_filtered['description_plus_topics'])
# Out:
# /Users/dlite/projects/ml_examples/covid19-repo-recommender/venv/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:385: UserWarning: Your stop_words may be inconsistent with your preprocessing. Tokenizing the stop words generated tokens ['ha', 'le', 'u', 'wa'] not in stop_words.
#   'stop_words.' % sorted(inconsistent))

# %%
########################################################
### Build predict function
########################################################

# %%
def text_recommender(input_df, word_vectorizer=word_vectorizer,  sparse_vector_matrix = sparse_vector_matrix, repo_lookup=repo_lookup):
    
    input_df['bag_of_words'] = input_df.apply(lambda x: ' '.join(x), axis = 1)
    
    # vectorize the inputted string
    #inputted_vector = word_vectorizer.transform(pd.Series(str(input_string)))
    inputted_vector = word_vectorizer.transform(input_df['bag_of_words'])
    
    # calculate cosine similarity with existing matrix
    one_dimension_cosine_sim = cosine_similarity(inputted_vector, sparse_vector_matrix)

    # creating a Series with the similarity scores in descending order
    score_series = pd.Series(one_dimension_cosine_sim[0]).sort_values(ascending = False)
    # only show matches that have some similarity
    score_series = score_series[score_series>0]

    # getting the indexes of the 10 most similar movies
    top_10_indexes = list(score_series.iloc[1:11].index)
    
    # initializing the empty list of recommended repo
    recommended_repos = repo_lookup.loc[top_10_indexes]
    return recommended_repos

# %%
class covid19RepoReco:
   
    ## defining objects needed for leadsModel prediction. 
    def __init__(self,
                 word_vectorizer,
                 sparse_vector_matrix,
                 repo_lookup,
                 text_recommender):
        
        ## Setting up all needed objects
        self.word_vectorizer = word_vectorizer
        self.sparse_vector_matrix = sparse_vector_matrix
        self.repo_lookup = repo_lookup
        self.text_recommender = text_recommender
    
    ## define function with processing and feeding data into prediction at the end
    def predict(self,context,model_input):
        output_df = self.text_recommender(model_input)
        return [output_df.to_dict('records')]

# %%
# Initialize the model
m = covid19RepoReco(word_vectorizer = word_vectorizer,
                                       sparse_vector_matrix = sparse_vector_matrix,
                                       repo_lookup = repo_lookup,
                                       text_recommender = text_recommender)

# Dump the model to disk
cloudpickle.dump(m, open("../models/model.pkl", "wb"))

# Forces uvicorn to restart (if running) as it currently only watches py files
# https://github.com/encode/uvicorn/pull/521/files
os.system("touch ../models/restart.py")

# Test the model
input = pd.DataFrame([["Python", "Data"]])
output = m.predict(None,input)
output
# Out:
# [[{'github_repo_url': 'https://github.com/mmarchegiani/covid-19',
#    'repo_description': 'data analysis of the covid-19 outbreak',
#    'topics': '',
#    'owner_repo_name': 'mmarchegiani/covid-19',
#    'owner_name': 'mmarchegiani',
#    'owner_type': 'User',
#    'organization_bio': '',
#    'repo_created_day': '2020-03-07',
#    'primary_language_name': 'Python',
#    'license_name': '',
#    'is_github_pages': False,
#    'has_readme': True,
#    'has_wiki': True,
#    'has_merged_prs': True,
#    'has_issues': True,
#    'has_contributor_guide': False,
#    'has_code_of_conduct': False,
#    'count_of_public_forks': 2,
#    'count_of_stars': 0,
#    'count_of_watchers': 0,
#    'count_distinct_contributors': 6,
#    'count_contributions': 26,
#    'count_commits': 17,
#    'count_commit_comments': 0,
#    'count_created_issues': 0,
#    'count_pull_requests_created': 9,
#    'count_pull_requests_reviews': 0,
#    'count_comments_on_issues_and_pull_requests': 0,
#    'language': 'en',
#    'is_latin_only_characters': True,
#    'repo_description_cleaned': 'data analysis of the covid19 outbreak',
#    'description_plus_topics': 'data analysis of the covid19 outbreak  Python'},
#   {'github_repo_url': 'https://github.com/covid19db/fetchers-python',
#    'repo_description': 'data source fetchers written in python',
#    'topics': '',
#    'owner_repo_name': 'covid19db/fetchers-python',
#    'owner_name': 'covid19db',
#    'owner_type': 'Organization',
#    'organization_bio': '',
#    'repo_created_day': '2020-03-24',
#    'primary_language_name': 'Python',
#    'license_name': 'mit',
#    'is_github_pages': False,
#    'has_readme': True,
#    'has_wiki': True,
#    'has_merged_prs': True,
#    'has_issues': True,
#    'has_contributor_guide': False,
#    'has_code_of_conduct': False,
#    'count_of_public_forks': 2,
#    'count_of_stars': 1,
#    'count_of_watchers': 1,
#    'count_distinct_contributors': 5,
#    'count_contributions': 14,
#    'count_commits': 10,
#    'count_commit_comments': 0,
#    'count_created_issues': 0,
#    'count_pull_requests_created': 2,
#    'count_pull_requests_reviews': 2,
#    'count_comments_on_issues_and_pull_requests': 0,
#    'language': 'en',
#    'is_latin_only_characters': True,
#    'repo_description_cleaned': 'data source fetchers written in python',
#    'description_plus_topics': 'data source fetchers written in python  Python'},
#   {'github_repo_url': 'https://github.com/sfbrigade/data-covid19-sfbayarea',
#    'repo_description': 'manual and automated processes of sourcing data for the stop-covid19-sfbayarea project',
#    'topics': 'data covid19 webscraping python',
#    'owner_repo_name': 'sfbrigade/data-covid19-sfbayarea',
#    'owner_name': 'sfbrigade',
#    'owner_type': 'Organization',
#    'organization_bio': 'a volunteer civic technology group.',
#    'repo_created_day': '2020-03-21',
#    'primary_language_name': 'Python',
#    'license_name': 'mit',
#    'is_github_pages': False,
#    'has_readme': True,
#    'has_wiki': True,
#    'has_merged_prs': True,
#    'has_issues': True,
#    'has_contributor_guide': False,
#    'has_code_of_conduct': False,
#    'count_of_public_forks': 2,
#    'count_of_stars': 0,
#    'count_of_watchers': 0,
#    'count_distinct_contributors': 5,
#    'count_contributions': 78,
#    'count_commits': 56,
#    'count_commit_comments': 0,
#    'count_created_issues': 6,
#    'count_pull_requests_created': 8,
#    'count_pull_requests_reviews': 2,
#    'count_comments_on_issues_and_pull_requests': 6,
#    'language': 'en',
#    'is_latin_only_characters': True,
#    'repo_description_cleaned': 'manual and automated processes of sourcing data for the stopcovid19sfbayarea project',
#    'description_plus_topics': 'manual and automated processes of sourcing data for the stopcovid19sfbayarea project data covid19 webscraping python Python'},
#   {'github_repo_url': 'https://github.com/eschnou/covid19-be',
#    'repo_description': 'collecting data on belgium covid-19 cases',
#    'topics': '',
#    'owner_repo_name': 'eschnou/covid19-be',
#    'owner_name': 'eschnou',
#    'owner_type': 'User',
#    'organization_bio': '',
#    'repo_created_day': '2020-03-12',
#    'primary_language_name': 'Python',
#    'license_name': 'cc0-1.0',
#    'is_github_pages': False,
#    'has_readme': True,
#    'has_wiki': True,
#    'has_merged_prs': True,
#    'has_issues': True,
#    'has_contributor_guide': False,
#    'has_code_of_conduct': False,
#    'count_of_public_forks': 3,
#    'count_of_stars': 16,
#    'count_of_watchers': 16,
#    'count_distinct_contributors': 7,
#    'count_contributions': 82,
#    'count_commits': 48,
#    'count_commit_comments': 1,
#    'count_created_issues': 4,
#    'count_pull_requests_created': 13,
#    'count_pull_requests_reviews': 1,
#    'count_comments_on_issues_and_pull_requests': 15,
#    'language': 'en',
#    'is_latin_only_characters': True,
#    'repo_description_cleaned': 'collecting data on belgium covid19 cases',
#    'description_plus_topics': 'collecting data on belgium covid19 cases  Python'},
#   {'github_repo_url': 'https://github.com/maxwellflitton/imperial-coronavirus-data-node',
#    'repo_description': 'a server for processing data',
#    'topics': '',
#    'owner_repo_name': 'maxwellflitton/imperial-coronavirus-data-node',
#    'owner_name': 'maxwellflitton',
#    'owner_type': 'User',
#    'organization_bio': '',
#    'repo_created_day': '2020-03-21',
#    'primary_language_name': 'Python',
#    'license_name': '',
#    'is_github_pages': False,
#    'has_readme': True,
#    'has_wiki': True,
#    'has_merged_prs': True,
#    'has_issues': True,
#    'has_contributor_guide': False,
#    'has_code_of_conduct': False,
#    'count_of_public_forks': 0,
#    'count_of_stars': 2,
#    'count_of_watchers': 2,
#    'count_distinct_contributors': 4,
#    'count_contributions': 54,
#    'count_commits': 38,
#    'count_commit_comments': 0,
#    'count_created_issues': 1,
#    'count_pull_requests_created': 9,
#    'count_pull_requests_reviews': 3,
#    'count_comments_on_issues_and_pull_requests': 3,
#    'language': 'en',
#    'is_latin_only_characters': True,
#    'repo_description_cleaned': 'a server for processing data',
#    'description_plus_topics': 'a server for processing data  Python'},
#   {'github_repo_url': 'https://github.com/Kamaropoulos/COVID19Py',
#    'repo_description': 'a tiny python package for easy access to up-to-date coronavirus (covid-19, sars-cov-2) cases data.',
#    'topics': 'python covid19 apiwrapper coronavirus covid19data coronavirustracking covid19',
#    'owner_repo_name': 'Kamaropoulos/COVID19Py',
#    'owner_name': 'Kamaropoulos',
#    'owner_type': 'User',
#    'organization_bio': '',
#    'repo_created_day': '2020-03-19',
#    'primary_language_name': 'Python',
#    'license_name': 'gpl-3.0',
#    'is_github_pages': False,
#    'has_readme': True,
#    'has_wiki': True,
#    'has_merged_prs': True,
#    'has_issues': True,
#    'has_contributor_guide': False,
#    'has_code_of_conduct': False,
#    'count_of_public_forks': 13,
#    'count_of_stars': 43,
#    'count_of_watchers': 43,
#    'count_distinct_contributors': 8,
#    'count_contributions': 68,
#    'count_commits': 29,
#    'count_commit_comments': 0,
#    'count_created_issues': 4,
#    'count_pull_requests_created': 6,
#    'count_pull_requests_reviews': 0,
#    'count_comments_on_issues_and_pull_requests': 29,
#    'language': 'en',
#    'is_latin_only_characters': True,
#    'repo_description_cleaned': 'a tiny python package for easy access to uptodate coronavirus covid19 sarscov2 cases data',
#    'description_plus_topics': 'a tiny python package for easy access to uptodate coronavirus covid19 sarscov2 cases data python covid19 apiwrapper coronavirus covid19data coronavirustracking covid19 Python'},
#   {'github_repo_url': 'https://github.com/covid-projections/covid-data-model',
#    'repo_description': 'data backend providing computed data for the graphs displayed at https://covidactnow.org',
#    'topics': '',
#    'owner_repo_name': 'covid-projections/covid-data-model',
#    'owner_name': 'covid-projections',
#    'owner_type': 'Organization',
#    'organization_bio': '',
#    'repo_created_day': '2020-03-17',
#    'primary_language_name': 'Python',
#    'license_name': 'mit',
#    'is_github_pages': False,
#    'has_readme': True,
#    'has_wiki': True,
#    'has_merged_prs': True,
#    'has_issues': True,
#    'has_contributor_guide': False,
#    'has_code_of_conduct': False,
#    'count_of_public_forks': 23,
#    'count_of_stars': 30,
#    'count_of_watchers': 30,
#    'count_distinct_contributors': 28,
#    'count_contributions': 989,
#    'count_commits': 583,
#    'count_commit_comments': 1,
#    'count_created_issues': 42,
#    'count_pull_requests_created': 86,
#    'count_pull_requests_reviews': 165,
#    'count_comments_on_issues_and_pull_requests': 112,
#    'language': 'en',
#    'is_latin_only_characters': True,
#    'repo_description_cleaned': 'data backend providing computed data for the graphs displayed at httpscovidactnoworg',
#    'description_plus_topics': 'data backend providing computed data for the graphs displayed at httpscovidactnoworg  Python'},
#   {'github_repo_url': 'https://github.com/cc-001/nyt-covid-19-plotter',
#    'repo_description': 'plots covid-19 data from the new york times with population data from wikipedia.',
#    'topics': '',
#    'owner_repo_name': 'cc-001/nyt-covid-19-plotter',
#    'owner_name': 'cc-001',
#    'owner_type': 'User',
#    'organization_bio': '',
#    'repo_created_day': '2020-03-28',
#    'primary_language_name': 'Python',
#    'license_name': '',
#    'is_github_pages': False,
#    'has_readme': True,
#    'has_wiki': True,
#    'has_merged_prs': True,
#    'has_issues': True,
#    'has_contributor_guide': False,
#    'has_code_of_conduct': False,
#    'count_of_public_forks': 1,
#    'count_of_stars': 1,
#    'count_of_watchers': 1,
#    'count_distinct_contributors': 2,
#    'count_contributions': 28,
#    'count_commits': 26,
#    'count_commit_comments': 0,
#    'count_created_issues': 0,
#    'count_pull_requests_created': 1,
#    'count_pull_requests_reviews': 1,
#    'count_comments_on_issues_and_pull_requests': 0,
#    'language': 'en',
#    'is_latin_only_characters': True,
#    'repo_description_cleaned': 'plots covid19 data from the new york times with population data from wikipedia',
#    'description_plus_topics': 'plots covid19 data from the new york times with population data from wikipedia  Python'},
#   {'github_repo_url': 'https://github.com/sudharshan-ashok/pycovid',
#    'repo_description': 'python package to easily access the most updated coronavirus data using python/pip',
#    'topics': '',
#    'owner_repo_name': 'sudharshan-ashok/pycovid',
#    'owner_name': 'sudharshan-ashok',
#    'owner_type': 'User',
#    'organization_bio': '',
#    'repo_created_day': '2020-03-09',
#    'primary_language_name': 'Python',
#    'license_name': 'mit',
#    'is_github_pages': False,
#    'has_readme': True,
#    'has_wiki': True,
#    'has_merged_prs': True,
#    'has_issues': True,
#    'has_contributor_guide': False,
#    'has_code_of_conduct': False,
#    'count_of_public_forks': 12,
#    'count_of_stars': 58,
#    'count_of_watchers': 58,
#    'count_distinct_contributors': 7,
#    'count_contributions': 42,
#    'count_commits': 7,
#    'count_commit_comments': 0,
#    'count_created_issues': 3,
#    'count_pull_requests_created': 8,
#    'count_pull_requests_reviews': 9,
#    'count_comments_on_issues_and_pull_requests': 15,
#    'language': 'en',
#    'is_latin_only_characters': True,
#    'repo_description_cleaned': 'python package to easily access the most updated coronavirus data using pythonpip',
#    'description_plus_topics': 'python package to easily access the most updated coronavirus data using pythonpip  Python'},
#   {'github_repo_url': 'https://github.com/inf-covid19/data',
#    'repo_description': 'scraping world-wide data about covid-19',
#    'topics': 'sarscov2 datasets covid19',
#    'owner_repo_name': 'inf-covid19/data',
#    'owner_name': 'inf-covid19',
#    'owner_type': 'Organization',
#    'organization_bio': 'datasets, analysis, and predictions about covid-19',
#    'repo_created_day': '2020-03-26',
#    'primary_language_name': 'Python',
#    'license_name': '',
#    'is_github_pages': True,
#    'has_readme': True,
#    'has_wiki': True,
#    'has_merged_prs': True,
#    'has_issues': True,
#    'has_contributor_guide': False,
#    'has_code_of_conduct': False,
#    'count_of_public_forks': 0,
#    'count_of_stars': 8,
#    'count_of_watchers': 8,
#    'count_distinct_contributors': 2,
#    'count_contributions': 41,
#    'count_commits': 39,
#    'count_commit_comments': 0,
#    'count_created_issues': 1,
#    'count_pull_requests_created': 1,
#    'count_pull_requests_reviews': 0,
#    'count_comments_on_issues_and_pull_requests': 0,
#    'language': 'en',
#    'is_latin_only_characters': True,
#    'repo_description_cleaned': 'scraping worldwide data about covid19',
#    'description_plus_topics': 'scraping worldwide data about covid19 sarscov2 datasets covid19 Python'}]]
